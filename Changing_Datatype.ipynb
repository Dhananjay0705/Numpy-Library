# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhananjay0705/Numpy-Library/blob/main/Changing_Datatype.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **Changing Datatype**

# %%
import numpy as np

# %%
a1 = np.arange(10)
a2 = np.arange(12,dtype = float).reshape(3,4)
a3 = np.arange(8).reshape(2,2,2)

# %%
## astype
a3.astype(np.int32)
# Out:
# array([[[0, 1],
#         [2, 3]],
#
#        [[4, 5],
#         [6, 7]]], dtype=int32)
