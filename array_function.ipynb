# %% [markdown]
# <a href="https://colab.research.google.com/github/Dhananjay0705/Numpy-Library/blob/main/array_function.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %% [markdown]
# **ARRAY FUNCTIONS**

# %%
import numpy as np

# %%
a1 = np.random.random((3,3))
a1 = np.round(a1*100)
a1
# Out:
# array([[ 2., 24., 91.],
#        [ 7., 81., 43.],
#        [48., 26., 29.]])

# %%
## max/min/sum/prod
## 0--> col , 1 ---> raws
np.max(a1,axis = 1) ## for rows
# Out:
# array([91., 81., 48.])
